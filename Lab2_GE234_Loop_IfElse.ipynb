# %% [markdown]
# <a href="https://colab.research.google.com/github/japenped/Lab_GE234_Kwandao/blob/main/Lab2_GE234_Loop_IfElse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛰️ Lab 2: การใช้งาน Loop และ If-Else
# ## วิชา GE 234 Basic Programming for Geographers
#
# ### 🎯 **วัตถุประสงค์**
# 1. เข้าใจโครงสร้างการควบคุมแบบ **Loop** (`for`, `while`) และ **เงื่อนไข** (`if-else`)
# 2. สามารถใช้ `for` และ `while` loop เพื่อประมวลผลข้อมูลซ้ำ ๆ ได้
# 3. ใช้ `if-else` เพื่อกำหนดเงื่อนไขในการตัดสินใจ
# 4. นำไปประยุกต์ใช้กับข้อมูลทางภูมิศาสตร์ เช่น การคัดกรองข้อมูลพิกัดและการวิเคราะห์ข้อมูล Raster
#
# ---
#
# ## 🔹 ตัวอย่างที่ 1: การใช้ `for loop` เพื่อแสดงค่าพิกัด

# %%
# พิกัดของสถานที่สำคัญในประเทศไทย
locations = {
    "Bangkok": (13.7563, 100.5018),
    "Chiang Mai": (18.7883, 98.9853),
    "Phuket": (7.8804, 98.3923),
    "Ubon Ratchathani": (15.2287, 104.8564)
}

# วนลูปแสดงค่าพิกัด
for city, coord in locations.items():
    print(f"{city}: Latitude {coord[0]}, Longitude {coord[1]}")
# Out:
# Bangkok: Latitude 13.7563, Longitude 100.5018
# Chiang Mai: Latitude 18.7883, Longitude 98.9853
# Phuket: Latitude 7.8804, Longitude 98.3923
# Ubon Ratchathani: Latitude 15.2287, Longitude 104.8564

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 2: การใช้ `if-else` กรองข้อมูลพิกัด

# %%
for city, coord in locations.items():
    if coord[0] > 16:
        print(f"{city} อยู่ทางภาคเหนือของประเทศไทย")
    else:
        print(f"{city} ไม่ใช่จังหวัดทางภาคเหนือ")
# Out:
# Bangkok ไม่ใช่จังหวัดทางภาคเหนือ
# Chiang Mai อยู่ทางภาคเหนือของประเทศไทย
# Phuket ไม่ใช่จังหวัดทางภาคเหนือ
# Ubon Ratchathani ไม่ใช่จังหวัดทางภาคเหนือ

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 3: ใช้ `while loop` นับจำนวนจุดข้อมูล

# %%
points = [(13.7563, 100.5018), (18.7883, 98.9853), (7.8804, 98.3923)]
count = 0

while count < len(points):
    print(f"Point {count + 1}: {points[count]}")
    count += 1
# Out:
# Point 1: (13.7563, 100.5018)
# Point 2: (18.7883, 98.9853)
# Point 3: (7.8804, 98.3923)

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 4: วิเคราะห์ข้อมูล Raster ด้วย `for loop`

# %%
import numpy as np

# จำลองข้อมูล NDVI (Normalized Difference Vegetation Index)
ndvi = np.array([
    [0.2, 0.4, 0.5],
    [0.1, 0.3, 0.7],
    [0.6, 0.8, 0.2]
])

# วนลูปตรวจสอบค่าพืชพรรณ
for row in range(ndvi.shape[0]):
    for col in range(ndvi.shape[1]):
        if ndvi[row, col] > 0.3:
            print(f"พิกัด ({row}, {col}) มีพืชพรรณหนาแน่น (NDVI={ndvi[row, col]})")
# Out:
# พิกัด (0, 1) มีพืชพรรณหนาแน่น (NDVI=0.4)
# พิกัด (0, 2) มีพืชพรรณหนาแน่น (NDVI=0.5)
# พิกัด (1, 2) มีพืชพรรณหนาแน่น (NDVI=0.7)
# พิกัด (2, 0) มีพืชพรรณหนาแน่น (NDVI=0.6)
# พิกัด (2, 1) มีพืชพรรณหนาแน่น (NDVI=0.8)

# %% [markdown]
# # 📝 **กิจกรรมในแลป**
#
# 1. **แบบฝึกหัด 1**: เขียน `for loop` เพื่อแสดงชื่อจังหวัดและพิกัดจากลิสต์ของคุณเอง
# 2. **แบบฝึกหัด 2**: ใช้ `if-else` เพื่อแยกแยะพื้นที่ที่เป็นภูเขาและพื้นที่ราบจากลิสต์ของพิกัด
# 3. **แบบฝึกหัด 3**: ใช้ `while loop` เพื่อวนลูปและแสดงค่าละติจูดจากลิสต์จนกว่าจะพบค่าต่ำกว่า 10°
# 4. **แบบฝึกหัด 4**: ใช้ `for loop` วิเคราะห์ค่า NDVI และหาค่าพื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2)

# %% [markdown]
# ### ✨ **เฉลยแบบฝึกหัด 1: แสดงชื่อจังหวัดและพิกัดจากลิสต์**

# %%
my_locations = {
    "Chiang Rai": (19.9039, 99.8325),
    "Phuket": (7.8804, 98.3923),
    "Nakhon Ratchasima": (14.9750, 102.0833),
    "Sa Kaeo": (13.8055, 102.0475),
    "Kanchanaburi": (14.0088, 99.5100)
}

print("--- แสดงจังหวัดและพิกัดจากลิสต์ของคุณเอง ---")
for city, coord in my_locations.items():
    print(f"จังหวัด {city}: ละติจูด {coord[0]}, ลองจิจูด {coord[1]}")
# Out:
# --- แสดงจังหวัดและพิกัดจากลิสต์ของคุณเอง ---
# จังหวัด Chiang Rai: ละติจูด 19.9039, ลองจิจูด 99.8325
# จังหวัด Phuket: ละติจูด 7.8804, ลองจิจูด 98.3923
# จังหวัด Nakhon Ratchasima: ละติจูด 14.975, ลองจิจูด 102.0833
# จังหวัด Sa Kaeo: ละติจูด 13.8055, ลองจิจูด 102.0475
# จังหวัด Kanchanaburi: ละติจูด 14.0088, ลองจิจูด 99.51

# %% [markdown]
# ### ✨ **เฉลยแบบฝึกหัด 2: ใช้ `if-else` แยกแยะพื้นที่ที่เป็นภูเขาและพื้นที่ราบ**

# %%
geographical_points = [
    ("จังหวัดเชียงราย", 18.5898, 98.4862), # พื้นที่ภูเขาสูง
    ("กรุงเทพมหานคร", 13.7563, 100.5018), # พื้นที่ราบลุ่ม
    ("จังหวัดภูเก็ต", 7.8804, 98.3923), # พื้นที่ชายฝั่ง/เกาะ
    ("จังหวัดเชียงใหม่", 18.7883, 98.9853), # พื้นที่ภาคเหนือ/ภูเขา
    ("จังหวัดพระนครศรีอยุธยา", 14.3567, 100.5750) # พื้นที่ราบภาคกลาง
]

print("--- แยกแยะพื้นที่ภูเขาและพื้นที่ราบ (ตามสมมติฐานง่ายๆ) ---")
# สมมติฐานอย่างง่าย: หากละติจูดสูงกว่า 16 องศา ถือว่าเป็นพื้นที่ที่อยู่ในเขตภูเขาหรือภาคเหนือตอนบน
# หากละติจูดต่ำกว่า 16 องศา ถือว่าเป็นพื้นที่ราบหรือภาคอื่นๆ
for name, lat, lon in geographical_points:
    if lat > 16.0: # เกณฑ์อย่างง่าย: ละติจูดสูงกว่า 16 องศา อาจเป็นพื้นที่ภูเขาทางเหนือ
        print(f"{name} (ละติจูด {lat}) : มีแนวโน้มเป็นพื้นที่ภูเขาหรืออยู่ทางภาคเหนือตอนบน")
    else:
        print(f"{name} (ละติจูด {lat}) : มีแนวโน้มเป็นพื้นที่ราบหรืออยู่ภาคกลาง/ภาคใต้")
# Out:
# --- แยกแยะพื้นที่ภูเขาและพื้นที่ราบ (ตามสมมติฐานง่ายๆ) ---
# จังหวัดเชียงราย (ละติจูด 18.5898) : มีแนวโน้มเป็นพื้นที่ภูเขาหรืออยู่ทางภาคเหนือตอนบน
# กรุงเทพมหานคร (ละติจูด 13.7563) : มีแนวโน้มเป็นพื้นที่ราบหรืออยู่ภาคกลาง/ภาคใต้
# จังหวัดภูเก็ต (ละติจูด 7.8804) : มีแนวโน้มเป็นพื้นที่ราบหรืออยู่ภาคกลาง/ภาคใต้
# จังหวัดเชียงใหม่ (ละติจูด 18.7883) : มีแนวโน้มเป็นพื้นที่ภูเขาหรืออยู่ทางภาคเหนือตอนบน
# จังหวัดพระนครศรีอยุธยา (ละติจูด 14.3567) : มีแนวโน้มเป็นพื้นที่ราบหรืออยู่ภาคกลาง/ภาคใต้

# %% [markdown]
# ### ✨ **เฉลยแบบฝึกหัด 3: ใช้ `while loop` เพื่อวนลูปและแสดงค่าละติจูดจากลิสต์จนกว่าจะพบค่าต่ำกว่า 10°**

# %%
points_for_while_loop = [
    ("Chiang Mai", 18.7883, 98.9853),
    ("Bangkok", 13.7563, 100.5018),
    ("Phuket", 7.8804, 98.3923), # ละติจูดต่ำกว่า 10
    ("Songkhla", 7.2023, 100.5982)
]

count = 0
print("--- แสดงค่าละติจูดจนกว่าจะพบค่าต่ำกว่า 10 องศา ---")
while count < len(points_for_while_loop):
    name, lat, lon = points_for_while_loop[count]
    if lat < 10.0:
        print(f"พบค่าละติจูดที่ต่ำกว่า 10 องศาที่ {name}: ละติจูด {lat}°")
        break
    else:
        print(f"กำลังประมวลผล {name}: ละติจูด {lat}°")
    count += 1

if count == len(points_for_while_loop) and lat >= 10.0:
    print("ไม่พบค่าละติจูดที่ต่ำกว่า 10 องศาในลิสต์")
# Out:
# --- แสดงค่าละติจูดจนกว่าจะพบค่าต่ำกว่า 10 องศา ---
# กำลังประมวลผล Chiang Mai: ละติจูด 18.7883°
# กำลังประมวลผล Bangkok: ละติจูด 13.7563°
# พบค่าละติจูดที่ต่ำกว่า 10 องศาที่ Phuket: ละติจูด 7.8804°

# %% [markdown]
# ### ✨ **เฉลยแบบฝึกหัด 4: ใช้ `for loop` วิเคราะห์ค่า NDVI และหาค่าพื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2)**

# %%
import numpy as np

# จำลองข้อมูล NDVI (Normalized Difference Vegetation Index)
# ค่าที่ต่ำกว่า 0.2 อาจบ่งชี้ถึงสภาพแห้งแล้งหรือพืชพรรณเบาบาง
ndvi_data = np.array([
    [0.25, 0.40, 0.15],
    [0.10, 0.35, 0.70],
    [0.60, 0.05, 0.22]
])

print("--- พื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2) ---")
for row in range(ndvi_data.shape[0]):
    for col in range(ndvi_data.shape[1]):
        if ndvi_data[row, col] < 0.2:
            print(f"พิกัด ({row}, {col}) มีสภาพแห้งแล้ง (NDVI={ndvi_data[row, col]})\n")
# Out:
# --- พื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2) ---
# พิกัด (0, 2) มีสภาพแห้งแล้ง (NDVI=0.15)
#
# พิกัด (1, 0) มีสภาพแห้งแล้ง (NDVI=0.1)
#
# พิกัด (2, 1) มีสภาพแห้งแล้ง (NDVI=0.05)
